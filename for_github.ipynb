# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd /content/drive/MyDrive/학부연구생/SimCTG
# Out:
# /content/drive/MyDrive/학부연구생/SimCTG

# %%
# !git clone https://KyungminPark-steck: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@github.com/KyungminPark-steck/SimCTG.git
# Out:
# Cloning into 'SimCTG'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
cd /content/drive/MyDrive/학부연구생/SimCTG
# Out:
# /content/drive/MyDrive/학부연구생/SimCTG

# %%
# !git config --global user.email 'kyungmin102911'
# !git config --global user.name 'KyungminPark-steck'
# !git config --global user.password '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'

# %%
# !pwd
# Out:
# /content/drive/MyDrive/학부연구생/SimCTG

# %%
# !git init
# !git remote add origin https://KyungminPark-steck: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@github.com/KyungminPark-steck/SimCTG.git

# %%
# !git add --all
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push --set-upstream origin main
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git commit -m 'first commit'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
#!echo "# 2021-1-Classification_4classes" >> README.md
# !git init
# !git config --global user.email "아이디"
# !git config --global user.name "닉네임"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://닉네임:비밀번호@github.com/닉네임/깃허브레포이름.git
# !git push -u origin main

# %%
# !echo "# SimCTG" >> README.md
# !git init
# !git add README.md
# !git config --global user.email "kyungmin102911@gmail.com"
# !git config --global user.name "KyungminPark-steck"
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://KyungminPark-steck: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@github.com/KyungminPark-steck/SimCTG.git
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/학부연구생/SimCTG/.git/
# [master (root-commit) 26ab3c4] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# To https://github.com/KyungminPark-steck/SimCTG.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/KyungminPark-steck/SimCTG.git'
# hint: Updates were rejected because the remote contains work that you do
# ...

# %%
#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
from os.path import join

# path to your project on Google Drive
PROJECT_PATH = '/content/drive/MyDrive/학부연구생/SimCTG'
# replace with your Github username
GIT_USERNAME = "KyunminPark-steck"
# definitely replace with your
GIT_TOKEN = "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"
# Replace with your github repository in this case we want
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "2023-HUFS-Debiasing-Research"

# It's good to print out the value if you are not sure
print("PROJECT_PATH: ", PROJECT_PATH)

# In case we haven't created the folder already; we will create a folder in the project path
# !mkdir "{PROJECT_PATH}"

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/학부연구생/SimCTG
# GIT_PATH:  https://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@github.com/KyunminPark-steck/2023-HUFS-Debiasing-Research.git

# %%
# !git config --global user.email 'kyungmin102911'
# !git config --global user.name 'KyungminPark-steck'
# !git config --global user.password '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'

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main

# %%
# !git push origin main

# %%
# !git add .
# !git commit -m "update from g-drive" #커밋메세지를 자유롭게 적어줍니다.
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/KyungminPark-steck/2023-HUFS-Debiasing-Research.git/'
